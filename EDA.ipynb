# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df= pd.read_csv("Airbnb.csv")

# %%
df.columns
# Out:
# Index(['Id', 'Property_type', 'RoomType', 'BedType', 'Min_Night', 'Max_Night',
#        'Cancel', 'Accomadate', 'Bedroom', 'amenities', 'Bed', 'Total_Reviews',
#        'Bathrooms', 'Price', 'Cleaning', 'ExtraPeople', 'Guests', 'Id_host',
#        'Location', 'Response', 'Host_neigh', 'Response_rate', 'Total_list',
#        'Vertify', 'Street', 'SubUrban', 'Gov_Area', 'Market', 'Country',
#        'C_Code', 'longitude', 'latitude', 'Avail_30', 'Avail_60', 'Avail_90',
#        'Avail_365', 'RScore_accur', 'RScore_neatness', 'RScore_checkin',
#        'RScore_comm', 'RScore_location', 'RScore_value', 'RScore_rate'],
#       dtype='object')

# %%
sn.boxplot(df['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
sn. barplot(data = df, x = "RoomType", y = "Price")
plt.show()

# %%
df.columns
# Out:
# Index(['Id', 'Property_type', 'RoomType', 'BedType', 'Min_Night', 'Max_Night',
#        'Cancel', 'Accomadate', 'Bedroom', 'amenities', 'Bed', 'Total_Reviews',
#        'Bathrooms', 'Price', 'Cleaning', 'ExtraPeople', 'Guests', 'Id_host',
#        'Location', 'Response', 'Host_neigh', 'Response_rate', 'Total_list',
#        'Vertify', 'Street', 'SubUrban', 'Gov_Area', 'Market', 'Country',
#        'C_Code', 'longitude', 'latitude', 'Avail_30', 'Avail_60', 'Avail_90',
#        'Avail_365', 'RScore_accur', 'RScore_neatness', 'RScore_checkin',
#        'RScore_comm', 'RScore_location', 'RScore_value', 'RScore_rate'],
#       dtype='object')

# %%
#rating = df[['Total_Reviews']]

#sn.pairplot
df3=df[['Price','Bedroom','Accomadate','Country']]
sn.pairplot(df3,hue='Country')
plt.show()

# %%
sn.scatterplot(data = df, x = 'Price', y = 'Total_Reviews')
plt.show()
